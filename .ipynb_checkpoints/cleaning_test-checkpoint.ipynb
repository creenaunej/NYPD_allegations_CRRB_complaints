# %% [markdown]
# Data cleaning

# %%
import pandas as pd
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
nypd_allegations = pd.read_csv("/Users/jordancreenaune/Documents/GitHub/NYPD_allegations/allegations.csv")

#A snapshot of the data.
nypd_allegations.head(3)
# Out:
#    unique_mos_id first_name last_name command_now  complaint_id  \
# 0          10004   Jonathan      Ruiz     078 PCT         42835
# 1          10007       John     Sears     078 PCT         24601
# 2          10007       John     Sears     078 PCT         24601
#
#    month_received  year_received  month_closed  year_closed  \
# 0               7           2019             5         2020
# 1              11           2011             8         2012
# 2              11           2011             8         2012
#
#   command_at_incident  ... mos_age_incident complainant_ethnicity  \
# 0             078 PCT  ...               32                 Black
# 1                PBBS  ...               24                 Black
# 2                PBBS  ...               24                 Black
#
#   complainant_gender complainant_age_incident           fado_type  \
# 0             Female                     38.0  Abuse of Authority
# 1               Male                     26.0         Discourtesy
# 2               Male                     26.0  Offensive Language
#
#                      allegation  precinct           contact_reason  \
# 0  Failure to provide RTKA card      78.0  Report-domestic dispute
# 1                        Action      67.0         Moving violation
# 2                          Race      67.0         Moving violation
#
#                 outcome_description                         board_disposition
# 0  No arrest made or summons issued  Substantiated (Command Lvl Instructions)
# 1   Moving violation summons issued                   Substantiated (Charges)
# 2   Moving violation summons issued                   Substantiated (Charges)
#
# [3 rows x 26 columns]

# %%
# Out:
# 31374

# %%
#When isolating a single officer to check duplicates

officer_example = nypd_allegations[nypd_allegations["unique_mos_id"] == 18731] 
officer_example
# Out:
#       unique_mos_id first_name last_name command_now  complaint_id  \
# 7846          18731     Daniel    Sbarra     DB CEIS          6832
# 7847          18731     Daniel    Sbarra     DB CEIS          6832
# 7848          18731     Daniel    Sbarra     DB CEIS          7174
# 7849          18731     Daniel    Sbarra     DB CEIS          7174
# 7850          18731     Daniel    Sbarra     DB CEIS          8351
# ...             ...        ...       ...         ...           ...
# 7916          18731     Daniel    Sbarra     DB CEIS         12387
# 7917          18731     Daniel    Sbarra     DB CEIS         14924
# 7918          18731     Daniel    Sbarra     DB CEIS         18088
# 7919          18731     Daniel    Sbarra     DB CEIS         19817
# 7920          18731     Daniel    Sbarra     DB CEIS         22856
#
#       month_received  year_received  month_closed  year_closed  \
# 7846               9           2003             2         2004
# 7847               9           2003             2         2004
# 7848               1           2004            12         2004
# 7849               1           2004            12         2004
# 7850              10           2004             7         2005
# ...              ...            ...           ...          ...
# 7916              10           2006            10         2007
# 7917              12           2007             8         2008
# 7918               4           2009             8         2010
# 7919               1           2010             4         2011
# 7920               3           2011            11         2011
#
#      command_at_incident  ... mos_age_incident complainant_ethnicity  \
# 7846             083 PCT  ...               27              Hispanic
# 7847             083 PCT  ...               27              Hispanic
# 7848             083 PCT  ...               28              Hispanic
# 7849             083 PCT  ...               28              Hispanic
# 7850             083 PCT  ...               28                 Black
# ...                  ...  ...              ...                   ...
# 7916             NARCBBN  ...               30                 Black
# 7917             NARCBBN  ...               32              Hispanic
# 7918             NARCBBN  ...               33                 Black
# 7919             NARCBBN  ...               34                 Black
# 7920             NARCBBN  ...               35                 Black
#
#      complainant_gender complainant_age_incident           fado_type  \
# 7846               Male                     39.0         Discourtesy
# 7847               Male                     39.0               Force
# 7848               Male                     30.0               Force
# 7849               Male                     30.0  Abuse of Authority
# 7850               Male                     28.0  Abuse of Authority
# ...                 ...                      ...                 ...
# 7916               Male                     28.0  Abuse of Authority
# 7917             Female                     39.0  Abuse of Authority
# 7918               Male                     15.0               Force
# 7919               Male                     18.0               Force
# 7920               Male                     53.0         Discourtesy
#
#           allegation  precinct                                contact_reason  \
# 7846            Word      83.0                                         Other
# 7847  Physical force      83.0                                         Other
# 7848  Physical force      83.0                                EDP aided case
# 7849           Other      83.0                                EDP aided case
# 7850    Vehicle stop      83.0                                         Other
# ...              ...       ...                                           ...
# 7916  Vehicle search      81.0    PD suspected C/V of violation/crime - auto
# 7917  Strip-searched      81.0                   Execution of search warrant
# 7918  Physical force      81.0                                         Other
# 7919  Physical force      81.0                   Execution of search warrant
# 7920            Word      81.0  PD suspected C/V of violation/crime - street
#
#                    outcome_description        board_disposition
# 7846  No arrest made or summons issued          Unsubstantiated
# 7847  No arrest made or summons issued               Exonerated
# 7848  No arrest made or summons issued          Unsubstantiated
# 7849  No arrest made or summons issued          Unsubstantiated
# 7850  No arrest made or summons issued  Substantiated (Charges)
# ...                                ...                      ...
# 7916    Arrest - other violation/crime          Unsubstantiated
# 7917  No arrest made or summons issued               Exonerated
# 7918    Arrest - other violation/crime          Unsubstantiated
# 7919    Arrest - other violation/crime               Exonerated
# 7920  No arrest made or summons issued          Unsubstantiated
#
# [75 rows x 26 columns]

# %%
#Check duplicates of columns 

#duplicates have been deleted from the df 
sbarra = officer_example[officer_example[['first_name', 'last_name', 'complaint_id','allegation']].duplicated() == False]

# %%
sbarra
# Out:
#       unique_mos_id first_name last_name command_now  complaint_id  \
# 7846          18731     Daniel    Sbarra     DB CEIS          6832
# 7847          18731     Daniel    Sbarra     DB CEIS          6832
# 7848          18731     Daniel    Sbarra     DB CEIS          7174
# 7849          18731     Daniel    Sbarra     DB CEIS          7174
# 7850          18731     Daniel    Sbarra     DB CEIS          8351
# ...             ...        ...       ...         ...           ...
# 7915          18731     Daniel    Sbarra     DB CEIS         12057
# 7917          18731     Daniel    Sbarra     DB CEIS         14924
# 7918          18731     Daniel    Sbarra     DB CEIS         18088
# 7919          18731     Daniel    Sbarra     DB CEIS         19817
# 7920          18731     Daniel    Sbarra     DB CEIS         22856
#
#       month_received  year_received  month_closed  year_closed  \
# 7846               9           2003             2         2004
# 7847               9           2003             2         2004
# 7848               1           2004            12         2004
# 7849               1           2004            12         2004
# 7850              10           2004             7         2005
# ...              ...            ...           ...          ...
# 7915               9           2006             3         2007
# 7917              12           2007             8         2008
# 7918               4           2009             8         2010
# 7919               1           2010             4         2011
# 7920               3           2011            11         2011
#
#      command_at_incident  ... mos_age_incident complainant_ethnicity  \
# 7846             083 PCT  ...               27              Hispanic
# 7847             083 PCT  ...               27              Hispanic
# 7848             083 PCT  ...               28              Hispanic
# 7849             083 PCT  ...               28              Hispanic
# 7850             083 PCT  ...               28                 Black
# ...                  ...  ...              ...                   ...
# 7915             NARCBBN  ...               30                 Black
# 7917             NARCBBN  ...               32              Hispanic
# 7918             NARCBBN  ...               33                 Black
# 7919             NARCBBN  ...               34                 Black
# 7920             NARCBBN  ...               35                 Black
#
#      complainant_gender complainant_age_incident           fado_type  \
# 7846               Male                     39.0         Discourtesy
# 7847               Male                     39.0               Force
# 7848               Male                     30.0               Force
# 7849               Male                     30.0  Abuse of Authority
# 7850               Male                     28.0  Abuse of Authority
# ...                 ...                      ...                 ...
# 7915               Male                     42.0  Abuse of Authority
# 7917             Female                     39.0  Abuse of Authority
# 7918               Male                     15.0               Force
# 7919               Male                     18.0               Force
# 7920               Male                     53.0         Discourtesy
#
#                                  allegation  precinct  \
# 7846                                   Word      83.0
# 7847                         Physical force      83.0
# 7848                         Physical force      83.0
# 7849                                  Other      83.0
# 7850                           Vehicle stop      83.0
# ...                                     ...       ...
# 7915  Refusal to provide name/shield number      81.0
# 7917                         Strip-searched      81.0
# 7918                         Physical force      81.0
# 7919                         Physical force      81.0
# 7920                                   Word      81.0
#
#                                     contact_reason  \
# 7846                                         Other
# 7847                                         Other
# 7848                                EDP aided case
# 7849                                EDP aided case
# 7850                                         Other
# ...                                            ...
# 7915  PD suspected C/V of violation/crime - street
# 7917                   Execution of search warrant
# 7918                                         Other
# 7919                   Execution of search warrant
# 7920  PD suspected C/V of violation/crime - street
#
#                    outcome_description                   board_disposition
# 7846  No arrest made or summons issued                     Unsubstantiated
# 7847  No arrest made or summons issued                          Exonerated
# 7848  No arrest made or summons issued                     Unsubstantiated
# 7849  No arrest made or summons issued                     Unsubstantiated
# 7850  No arrest made or summons issued             Substantiated (Charges)
# ...                                ...                                 ...
# 7915         Arrest - resisting arrest  Substantiated (Command Discipline)
# 7917  No arrest made or summons issued                          Exonerated
# 7918    Arrest - other violation/crime                     Unsubstantiated
# 7919    Arrest - other violation/crime                          Exonerated
# 7920  No arrest made or summons issued                     Unsubstantiated
#
# [73 rows x 26 columns]
